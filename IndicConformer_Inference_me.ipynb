# %% [markdown]
# # Install Dependencies

# %%
# !python3 -m pip install "cython==0.29.37"
# !python3 -m pip install "pyyaml==6.0.2"
# !python3 -m pip install "argparse==1.4.0"
# !python3 -m pip install "onnxruntime==1.19.0"
# !python3 -m pip install "tqdm==4.66.5"
# !python3 -m pip install "nemo_toolkit @ git+https://github.com/AI4Bharat/NeMo@nemo-v2"
# !python3 -m pip install "transformers==4.40.0"
# !python3 -m pip install "huggingface_hub==0.23"
# !python3 -m pip install "huggingface_hub==0.22.2"
# !python3 -m pip install "pytorch-lightning==2.4.0"
# !python3 -m pip install "hydra-core==1.3.2"
# !python3 -m pip install "librosa==0.10.2.post1"
# !python3 -m pip install "sentencepiece==0.2.0"
# !python3 -m pip install "pandas==2.2.2"
# !python3 -m pip install "lhotse==1.27.0"
# !python3 -m pip install "editdistance==0.8.1"
# !python3 -m pip install "jiwer==3.0.4"
# !python3 -m pip install "pyannote.audio==3.3.1"
# !python3 -m pip install "webdataset==0.2.100"
# !python3 -m pip install "datasets==2.21.0"
# !python3 -m pip install "IPython==8.27.0"
# !python3 -m pip install "joblib==1.4.2"
# !python3 -m pip install "argparse==1.4.0"
# !pip install numpy==1.26.4 --quiet
# !python3 -m pip install "numpy==1.26.4" --quiet
# Out:
# ...
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ...
#   Cloning https://github.com/AI4Bharat/NeMo (to revision nemo-v2) to /tmp/pip-install-vjkvc0n6/nemo-toolkit_d26cfa668658440f8dd71027878deacc
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Bharat/NeMo /tmp/pip-install-vjkvc0n6/nemo-toolkit_d26cfa668658440f8dd71027878deacc
#   Resolved https://github.com/AI4Bharat/NeMo to commit 8dce88cf8e94963e2033c3137f7b9993b51db88a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached huggingface_hub-0.23.2-py3-none-any.whl.metadata (12 kB)
# ...
# Using cached huggingface_hub-0.23.2-py3-none-any.whl (401 kB)
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.22.2
#     Uninstalling huggingface-hub-0.22.2:
# ...

# %% [markdown]
# # Download Model

# %%
# monolingual model
# !wget https://objectstore.e2enetworks.net/indic-asr-public/indicConformer/ai4b_indicConformer_hi.nemo -O hindi.nemo

# # multilingual model
# !wget https://objectstore.e2enetworks.net/indic-asr-public/indicConformer/ai4b_indicConformer_ta.nemo -O tamil.nemo

# multilingual model
# !wget https://objectstore.e2enetworks.net/indic-asr-public/indicConformer/ai4b_indicConformer_ur.nemo -O urdu.nemo

# !wget https://objectstore.e2enetworks.net/indicconformer/models/indicconformer_stt_te_hybrid_rnnt_large.nemo -O telugu.nemo
# !wget https://objectstore.e2enetworks.net/indicconformer/models/indicconformer_stt_te_hybrid_rnnt_large.nemo -O te_model.nemo



# model_path = "urdu.nemo"
# lang_id = "ur"

model_path = "te_model.nemo"
lang_id = "te"
# Out:
# --2025-07-04 13:18:29--  https://objectstore.e2enetworks.net/indicconformer/models/indicconformer_stt_te_hybrid_rnnt_large.nemo
# Resolving objectstore.e2enetworks.net (objectstore.e2enetworks.net)... 164.52.206.155, 164.52.210.97, 164.52.206.154, ...
# Connecting to objectstore.e2enetworks.net (objectstore.e2enetworks.net)|164.52.206.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 523192320 (499M) [application/octet-stream]
# Saving to: ‘te_model.nemo’
#
# te_model.nemo       100%[===================>] 498.96M  8.04MB/s    in 67s
#
# 2025-07-04 13:19:37 (7.48 MB/s) - ‘te_model.nemo’ saved [523192320/523192320]

# %% [markdown]
# # Necessary Imports

# %%
import torch
import soundfile as sf
import nemo.collections.asr as nemo_asr
import IPython

# %% [markdown]
# # Load Model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = nemo_asr.models.EncDecCTCModel.restore_from(restore_path=model_path)
model.eval() # inference mode
model = model.to(device) # transfer model to device
# Out:
# [NeMo I 2025-07-04 13:20:16 nemo_logging:381] _setup_tokenizer: detected an aggregate tokenizer
# [NeMo I 2025-07-04 13:20:16 nemo_logging:381] Tokenizer SentencePieceTokenizer initialized with 256 tokens
# [NeMo I 2025-07-04 13:20:16 nemo_logging:381] Tokenizer SentencePieceTokenizer initialized with 256 tokens
# [NeMo I 2025-07-04 13:20:16 nemo_logging:381] Tokenizer SentencePieceTokenizer initialized with 256 tokens
# [NeMo I 2025-07-04 13:20:16 nemo_logging:381] Tokenizer SentencePieceTokenizer initialized with 256 tokens
# [NeMo I 2025-07-04 13:20:16 nemo_logging:381] Tokenizer SentencePieceTokenizer initialized with 256 tokens
# [NeMo I 2025-07-04 13:20:16 nemo_logging:381] Tokenizer SentencePieceTokenizer initialized with 256 tokens
# [NeMo I 2025-07-04 13:20:16 nemo_logging:381] Tokenizer SentencePieceTokenizer initialized with 256 tokens
# [NeMo I 2025-07-04 13:20:16 nemo_logging:381] Tokenizer SentencePieceTokenizer initialized with 256 tokens
# ...

# %% [markdown]
# # Download sample audio file and perform preprocessing

# %%
# download and load audio
# MEDIA_URL = "test.wav"
# !wget $MEDIA_URL -O test.wav

# downsample, single channel
# !ffmpeg -i 20220502-091107_9000118609_50010986-all.mp3 -ac 1 -ar 16000 test_infer_ready.wav -y
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
IPython.display.Audio('test_infer_ready.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Inference using CTC Decoder

# %%
# !pip install numpy==1.26.4 --quiet
# # import os
# # os.kill(os.getpid(), 9)  # Auto-restart Colab

# %%
model.cur_decoder = "ctc"
ctc_text = model.transcribe(['test_infer_ready.wav'], batch_size=1,logprobs=False, language_id=lang_id)[0]
print(ctc_text)
# Out:
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s][NeMo W 2025-07-04 13:20:30 nemo_logging:393] /usr/local/lib/python3.11/dist-packages/nemo/collections/asr/parts/preprocessing/features.py:417: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#       with torch.cuda.amp.autocast(enabled=False):
#
# Transcribing: 100%|██████████| 1/1 [00:58<00:00, 58.17s/it]
# ...

# %% [markdown]
# # Inference using RNN-T Decoder

# %%
model.cur_decoder = "rnnt"
ctc_text = model.transcribe(['test_infer_ready.wav'], batch_size=1,logprobs=False, language_id=lang_id)[0]
print(ctc_text)
# Out:
# Transcribing: 100%|██████████| 1/1 [01:15<00:00, 75.75s/it]
# ...

# %%
# from huggingface_hub import login
# login()  # Then paste your Hugging Face token

# %%
# from google.colab import userdata
# userdata.get('hugging_face')
# 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

# %%
# !pip install --break-system-packages git+https://github.com/AI4Bharat/IndicTransTokenizer.git

# %%
model_name = "ai4bharat/indictrans2-indic-en-1B"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name, trust_remote_code=True)

def translate_to_english(text, source_lang="tel_Telu", target_lang="eng_Latn"):
    input_text = f"{source_lang} {target_lang} {text}"
    inputs = tokenizer(input_text, return_tensors="pt", padding=True)
    outputs = model.generate(**inputs, max_length=512)
    return tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]

# ctc_text = "మీరు చెప్పిన విషయం నాకు అర్థం కాలేదు"
english_translation = translate_to_english(ctc_text)
print("📘 Translated English:\n", english_translation)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1059 > 256). Running this sequence through the model will result in indexing errors
# 📘 Translated English:
#  [ ] If you have a good internal financial management system and you have a good working relationship with the team, you have a good working relationship with the team, and you have a good working relationship with the team, and you have a good working relationship with the team, and you have a good working relationship with the team, and you have a good working relationship with the team, and you have a good working relationship with the team, and you have a good working relationship with the team.
