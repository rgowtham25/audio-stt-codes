# %%
# !git clone https://github.com/MahmoudAshraf97/whisper-diarization
# !pip install git+https://github.com/m-bain/whisperx.git@78dcdfaab51005aa703ee21175f01ed31bc248560
# !pip install --no-build-isolation nemo_toolkit[asr]==1.23.0
# !pip install --no-deps git+https://github.com/facebookresearch/demucs#egg=demucs
# !pip install git+https://github.com/oliverguhr/deepmultilingualpunctuation.git
# !pip install git+https://github.com/MahmoudAshraf97/ctc-forced-aligner.git
# Out:
# Cloning into 'whisper-diarization'...
# remote: Enumerating objects: 411, done.
# remote: Counting objects: 100% (289/289), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 411 (delta 243), reused 178 (delta 178), pack-reused 122 (from 1)
# Receiving objects: 100% (411/411), 467.84 KiB | 8.21 MiB/s, done.
# Resolving deltas: 100% (268/268), done.
# ...
#   Cloning https://github.com/m-bain/whisperx.git (to revision 78dcdfaab51005aa703ee21175f01ed31bc248560) to /tmp/pip-req-build-sc4u_mzr
#   Running command git clone --filter=blob:none --quiet https://github.com/m-bain/whisperx.git /tmp/pip-req-build-sc4u_mzr
#   WARNING: Did not find branch or tag '78dcdfaab51005aa703ee21175f01ed31bc248560', assuming revision or ref.
#   Running command git checkout -q 78dcdfaab51005aa703ee21175f01ed31bc248560
#   error: pathspec '78dcdfaab51005aa703ee21175f01ed31bc248560' did not match any file(s) known to git
#   error: subprocess-exited-with-error
#
# ...

# %%
import glob, os
audioFiles = glob.glob("/content/*.*")
os.chdir("/content/whisper-diarization")
for i in range(len(audioFiles)):
    for audioFile in glob.glob(audioFiles[i]):
        baseFile = os.path.splitext(audioFile)[0]
        # !python diarize_parallel.py --whisper-model large-v3 -a "$audioFile"
        # !rm "$audioFile"
        # !zip "$baseFile".zip "$baseFile".srt "$baseFile".txt
        # !rm "$baseFile".srt "$baseFile".txt
# Out:
# Traceback (most recent call last):
#   File "/content/whisper-diarization/diarize_parallel.py", line 7, in <module>
#     import faster_whisper
# ModuleNotFoundError: No module named 'faster_whisper'
# 	zip warning: name not matched: /content/test.srt
# 	zip warning: name not matched: /content/test.txt
#
# zip error: Nothing to do! (/content/test.zip)
# rm: cannot remove '/content/test.srt': No such file or directory
# rm: cannot remove '/content/test.txt': No such file or directory
